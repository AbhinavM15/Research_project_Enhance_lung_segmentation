# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
# !unzip ""

# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

from glob import glob
from tqdm import tqdm

# %%
path = '/content/drive/MyDrive/research2/segmentation/train++/augmentation'
os.mkdir(path)

# %%
path = '/content/drive/MyDrive/research2/segmentation/test++'
os.mkdir(path)

# %%
path = '/content/drive/MyDrive/research2/segmentation/train++/dilate'
os.mkdir(path)

# %%
path = '/content/drive/MyDrive/research2/segmentation/train++/image'
os.mkdir(path)

# %%
path = '/content/drive/MyDrive/research2/segmentation/train++/mask'
os.mkdir(path)

# %%
input_dir = os.path.join('/content','drive','MyDrive','research2')
segmentation_dir = os.path.join(input_dir,'segmentation')
segmentation_test_dir = os.path.join(segmentation_dir,'test++')
segmentation_train_dir = os.path.join(segmentation_dir,'train++')
segmentation_aug_dir = os.path.join(segmentation_train_dir,'augmentation')
segmentation_image_dir = os.path.join(segmentation_train_dir,'image')
segmentation_mask_dir= os.path.join(segmentation_train_dir,"mask")
segmentation_dilate_dir = os.path.join(segmentation_train_dir,"dilate")
shenzhen_train_dir = os.path.join(input_dir,"ChinaSet_AllFiles")
shenzhen_image_dir = os.path.join(shenzhen_train_dir,"CXR_png")
shenzhen_mask_dir = os.path.join(shenzhen_train_dir,"mask","mask1")
montgomery_train_dir = os.path.join(input_dir,"MontgomerySet")
montgomery_image_dir = os.path.join(montgomery_train_dir,"CXR_png")
montgomery_left_mask_dir = os.path.join(montgomery_train_dir,"ManualMask","leftMask")
montgomery_right_mask_dir = os.path.join(montgomery_train_dir ,"ManualMask","rightMask")
DILATE_KERNEL = np.ones((15, 15), np.uint8)
BATCH_SIZE=2
EPOCHS=40

# %%
train_dir_1 = glob(os.path.join(segmentation_dir,'train++','image',"*.png"))
file=len(train_dir_1)
file 
test_dir_1 = glob(os.path.join(segmentation_dir,'test++',"*.png"))
file1=len(test_dir_1)
file1
# Out:
# 0

# %%
file
# Out:
# 0

# %%
print(input_dir)
print(segmentation_dir)
print(segmentation_test_dir)
print(segmentation_train_dir)
print(segmentation_aug_dir)
print(segmentation_image_dir)
print(segmentation_mask_dir)
print(segmentation_dilate_dir)
print(shenzhen_train_dir)
print(shenzhen_image_dir)
print(shenzhen_mask_dir)
print(montgomery_train_dir)
print(montgomery_image_dir)
print(montgomery_left_mask_dir)
print(montgomery_right_mask_dir)
# Out:
# /content/drive/MyDrive/research2
# /content/drive/MyDrive/research2/segmentation
# /content/drive/MyDrive/research2/segmentation/test++
# /content/drive/MyDrive/research2/segmentation/train++
# /content/drive/MyDrive/research2/segmentation/train++/augmentation
# /content/drive/MyDrive/research2/segmentation/train++/image
# /content/drive/MyDrive/research2/segmentation/train++/mask
# /content/drive/MyDrive/research2/segmentation/train++/dilate
# /content/drive/MyDrive/research2/ChinaSet_AllFiles
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1
# /content/drive/MyDrive/research2/MontgomerySet
# /content/drive/MyDrive/research2/MontgomerySet/CXR_png
# /content/drive/MyDrive/research2/MontgomerySet/ManualMask/leftMask
# /content/drive/MyDrive/research2/MontgomerySet/ManualMask/rightMask

# %%
montgomery_left_mask_dir_1 = glob(os.path.join(montgomery_left_mask_dir,"*.png"))
montgomery_test = montgomery_left_mask_dir_1[0:50]
montgomery_train = montgomery_left_mask_dir_1[50:]
for left_image_file in tqdm(montgomery_left_mask_dir_1):
    base_file = os.path.basename(left_image_file)
    image_file = os.path.join(montgomery_image_dir, base_file)
    right_image_file = os.path.join(montgomery_right_mask_dir, base_file)

    image = cv2.imread(image_file)
    left_mask = cv2.imread(left_image_file, cv2.IMREAD_GRAYSCALE)
    right_mask = cv2.imread(right_image_file, cv2.IMREAD_GRAYSCALE)
    
    image = cv2.resize(image, (512, 512))
    left_mask = cv2.resize(left_mask, (512, 512))
    right_mask = cv2.resize(right_mask, (512, 512))
    
    mask = np.maximum(left_mask, right_mask)
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (left_image_file in montgomery_train):
        cv2.imwrite(os.path.join(segmentation_image_dir, base_file), \
                    image)
        cv2.imwrite(os.path.join(segmentation_mask_dir, base_file), \
                    mask)
        cv2.imwrite(os.path.join(segmentation_dilate_dir, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)
        cv2.imwrite(os.path.join(segmentation_test_dir, base_file), \
                    image)
        cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 138/138 [03:47<00:00,  1.65s/it]

# %%
  def add_colored_dilate(image,mask_image,dilate_image):
     mask_image_gray = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)
     dilate_image_gray = cv2.cvtColor(dilate_image,cv2.COLOR_BGR2GRAY)
     mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_gray)
     dilate = cv2.bitwise_and(dilate_image,dilate_image,mask=dilate_image_gray)
     mask_coord = np.where(mask!=[0,0,0])
     dilate_coord = np.where(dilate!=[0,0,0])

     mask[mask_coord[0],mask_coord[1],:] = [255,0,0]
     dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

     ret = cv2.addWeighted(image,0.7,dilate,0.3,0)
     ret = cv2.addWeighted(ret,0.7,mask,0.3,0)

     return ret
  def add_colored_mask(image,mask_image):
    mask_image_grey = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)

    mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_grey)

    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:] = [255,0,0]

    ret = cv2.addWeighted(image,0.7,mask,0.3,0)

    return ret
  def diff_mask(ref_image,mask_image):
    mask_image_gray = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)

    mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_gray)

    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:] = [255,0,0]

    ret = cv2.addWeighted(ref_image,0.7,mask,0.3,0)
    return ret

# %%
base_file = os.path.basename(montgomery_train[0])

image_file = os.path.join(segmentation_image_dir,base_file)
mask_image_file = os.path.join(segmentation_mask_dir,base_file)

dilate_image_file = os.path.join(segmentation_dilate_dir,base_file)
image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image,mask_image,dilate_image)
fig, axs = plt.subplots( 2, 4, figsize=(15, 8))
axs[0,0].set_title("X-Ray")
axs[0,0].imshow(image)

axs[0,1].set_title("Mask")
axs[0,1].imshow(mask_image)
  
axs[0,2].set_title('Dilate')
axs[0,2].imshow(dilate_image)

axs[0,3].set_title("Merged")
axs[0,3].imshow(merged_image)


base_file = os.path.basename(montgomery_test[0])
filename,fileext  = os.path.splitext( base_file)
image_file = os.path.join(segmentation_test_dir,base_file)
mask_image_file = os.path.join(segmentation_test_dir, \
                                  "%s_mask%s" %(filename,fileext) )
dilate_image_file = os.path.join(segmentation_test_dir, \
                                    "%s_dilate%s" %(filename,fileext))
image = cv2.imread(image_file)

mask_image =cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image,mask_image,dilate_image)
axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
shenzhen_mask_dir_1 = glob(os.path.join(shenzhen_mask_dir,'*.png'))
shenzhen_test = shenzhen_mask_dir_1[0:50]
shenzhen_train = shenzhen_mask_dir_1[50:]
for mask_file in tqdm(shenzhen_mask_dir_1):
  base_file = os.path.basename(mask_file).replace("_mask","")
  image_file = os.path.join(shenzhen_image_dir,base_file)
  image = cv2.imread(image_file)
  print(image_file)
# Out:
#  43%|████▎     | 246/566 [02:50<05:57,  1.12s/it]
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png/CHNCXR_0372_1.png
#  44%|████▎     | 247/566 [02:51<05:32,  1.04s/it]
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png/CHNCXR_0435_1.png
#  44%|████▍     | 248/566 [02:51<04:40,  1.13it/s]
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png/CHNCXR_0363_1.png
#  44%|████▍     | 249/566 [02:52<04:34,  1.15it/s]
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png/CHNCXR_0399_1.png
#  44%|████▍     | 250/566 [02:53<04:33,  1.16it/s]
# /content/drive/MyDrive/research2/ChinaSet_AllFiles/CXR_png/CHNCXR_0412_1.png
#  44%|████▍     | 250/566 [02:54<03:40,  1.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a99f54ee1b9d> in <module>()
#       5   base_file = os.path.basename(mask_file).replace("_mask","")
#       6   image_file = os.path.join(shenzhen_image_dir,base_file)
# ----> 7   image = cv2.imread(image_file)
#       8   print(image_file)
#       9
#
# KeyboardInterrupt:

# %%
shenzhen_mask_dir_1 = glob(os.path.join(shenzhen_mask_dir,'*.png'))
shenzhen_test = shenzhen_mask_dir_1[0:50]
shenzhen_train = shenzhen_mask_dir_1[50:]
for mask_file in tqdm(shenzhen_mask_dir_1):
  base_file = os.path.basename(mask_file).replace("_mask","")
  image_file = os.path.join(shenzhen_image_dir,base_file)
  
  image = cv2.imread(image_file)
  mask = cv2.imread(mask_file,cv2.IMREAD_GRAYSCALE)
  image = cv2.resize(image,(512,512))
  mask = cv2.resize(mask,(512,512))

  mask_dilate = cv2.dilate(mask,DILATE_KERNEL,iterations=1)

  if (mask_file in shenzhen_train):
        cv2.imwrite(os.path.join(segmentation_image_dir , base_file), \
                    image)
        cv2.imwrite(os.path.join(segmentation_mask_dir, base_file), \
                    mask)
        cv2.imwrite(os.path.join(segmentation_dilate_dir, base_file), \
                    mask_dilate)
      
  else:
    filename,fileext = os.path.splitext(base_file)
    cv2.imwrite(os.path.join(segmentation_test_dir, base_file), \
                    image)
    cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_mask%s" % (filename, fileext)), mask)
    cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)

# %%
base_file = os.path.basename(shenzhen_train[0].replace("_mask",""))
image_file = os.path.join(segmentation_image_dir,base_file)
mask_image_file = os.path.join(segmentation_dilate_dir,base_file)
dilate_image_file = os.path.join(segmentation_dilate_dir,base_file)
image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image,mask_image,dilate_image)
fig,axs = plt.subplots(2,4,figsize=(15,8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(shenzhen_test[0].replace("_mask",""))
image_file = os.path.join(segmentation_test_dir,base_file)
filename,fileext = os.path.splitext(base_file)
mask_image_file = os.path.join(segmentation_test_dir, \
                               "%s_mask%s" % (filename, fileext))

filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(segmentation_test_dir, base_file)
mask_image_file = os.path.join(segmentation_test_dir, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(segmentation_test_dir, \
                                 "%s_dilate%s" % (filename, fileext))
image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
train_files = glob(os.path.join(segmentation_image_dir, "*.png"))
test_files = glob(os.path.join(segmentation_test_dir, "*.png"))
mask_files = glob(os.path.join(segmentation_mask_dir, "*.png"))
dilate_files = glob(os.path.join(segmentation_dilate_dir, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (604, 400, 604, 604)

# %%
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
def mean_iou(y_true, y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    iou = (true_positives)/(possible_negatives - true_negatives + possible_positives + K.epsilon())
    return K.mean(iou)  
  
def sensitivity(y_true,y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives+K.epsilon())

def specificity(y_true,y_pred):
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    return true_negatives / (possible_negatives+K.epsilon())



def precision(y_true, y_pred):
    """ Precision metric. Only computes a batch-wise average of precision. Computes the precision, a metric for multi-label classification of
    how many selected items are relevant."""
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    """ Recall metric. Only computes a batch-wise average of recall. Computes the recall, a metric for multi-label classification of
    how many relevant items are selected. """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def unet_plus (input_size=(512,512,1)):
  inputs = Input(input_size)

# %%
def unet_plus (input_size=(512,512,1)):
  inputs = Input(input_size)
  
  conv1_1 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(inputs)
  conv1_1 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv1_1)
  pool1 = MaxPooling2D((2,2),strides=(2,2))(conv1_1)

  conv2_1 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(pool1)
  conv2_1 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal',padding='same')(conv2_1)
  pool2 = MaxPooling2D((2,2), strides=(2,2))(conv2_1)

  up1_2 =Conv2DTranspose(32, (2,2), strides=(2,2), padding='same')(conv2_1)
  conv1_2 = concatenate([up1_2, conv1_1],axis=3)
  conv1_2 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same' )(conv1_2)
  conv1_2 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv1_2)

  conv3_1 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(pool2)
  conv3_1 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv3_1)
  pool3 = MaxPooling2D((2,2),strides = (2,2))(conv3_1)

  up2_2 = Conv2DTranspose(64, (2,2), strides=(2,2), padding ='same')(conv3_1)
  conv2_2 = concatenate([up2_2,conv2_1],axis=3)
  conv2_2 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv2_2)
  conv2_2 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal',padding='same')(conv2_2)

  up1_3 = Conv2DTranspose(32, (2,2), strides=(2,2), padding='same')(conv2_2)
  conv1_3 = concatenate([up1_3, conv1_1, conv1_2 ], axis=3)
  conv1_3 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv1_3)
  conv1_3 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal',padding='same')(conv1_3)

  conv4_1 = Conv2D(256, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(pool3)
  conv4_1 = Conv2D(256, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv4_1)
  pool4 = MaxPooling2D((2,2), strides=(2,2))(conv4_1)

  up3_2 = Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(conv4_1)
  conv3_2 = concatenate([up3_2,conv3_1], axis=3)
  conv3_2 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv3_2)
  conv3_2 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv3_2)

  up2_3 = Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(conv3_2)
  conv2_3 = concatenate([up2_3,conv2_1,conv2_2],axis=3)
  conv2_3 = Conv2D(64, (3,3), activation='relu', kernel_initializer = 'he_normal',padding = 'same')(conv2_3)
  conv2_3 = Conv2D(64, (3,3), activation='relu', kernel_initializer = 'he_normal',padding='same')(conv2_3)

  up1_4 = Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(conv2_3)
  conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3],axis=3)
  conv1_4 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv1_4)
  conv1_4 = Conv2D(32, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv1_4)

  conv5_1 = Conv2D(512, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(pool4)
  conv5_1 = Conv2D(512, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv5_1)

  up4_2 = Conv2DTranspose(256, (2,2), strides=(2,2), padding='same')(conv5_1)
  conv4_2 = concatenate([up4_2,conv4_1], axis=3)
  conv4_2 = Conv2D(256, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv4_2)
  conv4_2 = Conv2D(256, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv4_2)

  up3_3 = Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(conv4_2)
  conv3_3 = concatenate([up3_3, conv3_1, conv3_2],axis=3)
  conv3_3 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv3_3)
  conv3_3 = Conv2D(128, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv3_3)

  up2_4 = Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(conv3_3)
  conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3],axis=3)
  conv2_4 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv2_4)
  conv2_4 = Conv2D(64, (3,3), activation='relu',kernel_initializer = 'he_normal', padding='same')(conv2_4)

  up1_5 = Conv2DTranspose(32 ,(2,2), strides=(2,2),padding='same')(conv2_4)
  conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], axis=3)
  conv1_5 = Conv2D(32, (3,3), activation='relu', kernel_initializer = 'he_normal',padding='same')(conv1_5)
  conv1_5 = Conv2D(32, (3,3), activation='relu', kernel_initializer = 'he_normal',padding='same')(conv1_5)

  nestnet_output = Conv2D(1,(1,1),activation='sigmoid', padding='same')(conv1_5)

  return Model(inputs=[inputs],outputs=[nestnet_output])

# %%
def test_load_image(test_file, target_size=(256,256)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img = img / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files, target_size=(256,256)):
    for test_file in test_files:
        yield test_load_image(test_file, target_size)
        
def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %%
def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

test_files = [test_file for test_file in glob(os.path.join(segmentation_test_dir, "*.png")) \
              if ("_mask" not in test_file \
                  and "_dilate" not in test_file \
                  and "_predict" not in test_file)]

validation_data = (test_load_image(test_files[0], target_size=(512, 512)),
                    test_load_image(add_suffix(test_files[0], "dilate"), target_size=(512, 512)))

len(test_files), len(validation_data)
# Out:
# (100, 2)

# %%
r1=test_load_image(test_files[0],target_size=(512,512))
print(r1.shape)
# Out:
# (1, 512, 512, 1)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(BATCH_SIZE,
                            segmentation_train_dir,
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512),
                            save_to_dir=os.path.abspath(segmentation_aug_dir))

model = unet_plus(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy',mean_iou,sensitivity,specificity,precision,recall])
model.summary()

model_checkpoint = ModelCheckpoint('unet_lung_seg.hdf5', 
                                   monitor='loss', 
                                   verbose=1, 
                                   save_best_only=True)

history = model.fit(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE, 
                              epochs=EPOCHS, 
                              callbacks=[model_checkpoint],
                              validation_data = validation_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 128 147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 512, 512, 32) 8224        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 64) 0           conv2d_transpose[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 384 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 32) 18464       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 128 442496      concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 192 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 128 147584      conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 96) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 512, 32) 27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 256 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 147520      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 512, 512, 128 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 36896       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 512, 512, 160 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 512, 512, 32) 46112       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 512, 512, 1)  33          conv2d_29[0][0]
# ==================================================================================================
# Total params: 9,041,601
# Trainable params: 9,041,601
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Found 604 images belonging to 1 classes.
# Found 604 images belonging to 1 classes.
# Epoch 1/40
# 302/302 [==============================] - 184s 407ms/step - loss: -0.4444 - dice_coef: 0.4444 - binary_accuracy: 0.3405 - mean_iou: 0.3133 - sensitivity: 0.9674 - specificity: 0.0577 - precision: 0.3182 - recall: 0.9674 - val_loss: -0.4836 - val_dice_coef: 0.4836 - val_binary_accuracy: 0.6899 - val_mean_iou: 0.3614 - val_sensitivity: 0.5919 - val_specificity: 0.7318 - val_precision: 0.4813 - val_recall: 0.5919
#
# Epoch 00001: loss improved from inf to -0.48780, saving model to unet_lung_seg.hdf5
# Epoch 2/40
# 302/302 [==============================] - 124s 410ms/step - loss: -0.6489 - dice_coef: 0.6489 - binary_accuracy: 0.7074 - mean_iou: 0.4924 - sensitivity: 0.9063 - specificity: 0.6188 - precision: 0.5304 - recall: 0.9063 - val_loss: -0.7534 - val_dice_coef: 0.7534 - val_binary_accuracy: 0.8187 - val_mean_iou: 0.6054 - val_sensitivity: 0.9369 - val_specificity: 0.7697 - val_precision: 0.6311 - val_recall: 0.9369
#
# Epoch 00002: loss improved from -0.48780 to -0.67529, saving model to unet_lung_seg.hdf5
# Epoch 3/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.7256 - dice_coef: 0.7256 - binary_accuracy: 0.7936 - mean_iou: 0.5755 - sensitivity: 0.8670 - specificity: 0.7607 - precision: 0.6573 - recall: 0.8670 - val_loss: -0.8896 - val_dice_coef: 0.8896 - val_binary_accuracy: 0.9402 - val_mean_iou: 0.8114 - val_sensitivity: 0.8630 - val_specificity: 0.9732 - val_precision: 0.9313 - val_recall: 0.8630
#
# Epoch 00003: loss improved from -0.67529 to -0.75360, saving model to unet_lung_seg.hdf5
# Epoch 4/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.8431 - dice_coef: 0.8431 - binary_accuracy: 0.9056 - mean_iou: 0.7343 - sensitivity: 0.8342 - specificity: 0.9377 - precision: 0.8727 - recall: 0.8342 - val_loss: -0.8859 - val_dice_coef: 0.8859 - val_binary_accuracy: 0.9376 - val_mean_iou: 0.7979 - val_sensitivity: 0.8255 - val_specificity: 0.9855 - val_precision: 0.9598 - val_recall: 0.8255
#
# Epoch 00004: loss improved from -0.75360 to -0.85121, saving model to unet_lung_seg.hdf5
# Epoch 5/40
# 302/302 [==============================] - 126s 417ms/step - loss: -0.8683 - dice_coef: 0.8683 - binary_accuracy: 0.9200 - mean_iou: 0.7714 - sensitivity: 0.8608 - specificity: 0.9469 - precision: 0.8873 - recall: 0.8608 - val_loss: -0.8854 - val_dice_coef: 0.8854 - val_binary_accuracy: 0.9357 - val_mean_iou: 0.7977 - val_sensitivity: 0.8504 - val_specificity: 0.9722 - val_precision: 0.9278 - val_recall: 0.8504
#
# Epoch 00005: loss improved from -0.85121 to -0.86849, saving model to unet_lung_seg.hdf5
# Epoch 6/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.8838 - dice_coef: 0.8838 - binary_accuracy: 0.9289 - mean_iou: 0.7953 - sensitivity: 0.8796 - specificity: 0.9520 - precision: 0.8980 - recall: 0.8796 - val_loss: -0.9102 - val_dice_coef: 0.9102 - val_binary_accuracy: 0.9506 - val_mean_iou: 0.8411 - val_sensitivity: 0.8735 - val_specificity: 0.9838 - val_precision: 0.9578 - val_recall: 0.8735
#
# Epoch 00006: loss improved from -0.86849 to -0.88209, saving model to unet_lung_seg.hdf5
# Epoch 7/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.8946 - dice_coef: 0.8946 - binary_accuracy: 0.9362 - mean_iou: 0.8133 - sensitivity: 0.8906 - specificity: 0.9577 - precision: 0.9067 - recall: 0.8906 - val_loss: -0.9157 - val_dice_coef: 0.9157 - val_binary_accuracy: 0.9523 - val_mean_iou: 0.8479 - val_sensitivity: 0.8896 - val_specificity: 0.9793 - val_precision: 0.9476 - val_recall: 0.8896
#
# Epoch 00007: loss improved from -0.88209 to -0.89759, saving model to unet_lung_seg.hdf5
# Epoch 8/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.8957 - dice_coef: 0.8957 - binary_accuracy: 0.9364 - mean_iou: 0.8150 - sensitivity: 0.8983 - specificity: 0.9529 - precision: 0.9040 - recall: 0.8983 - val_loss: -0.9060 - val_dice_coef: 0.9060 - val_binary_accuracy: 0.9490 - val_mean_iou: 0.8345 - val_sensitivity: 0.8590 - val_specificity: 0.9876 - val_precision: 0.9670 - val_recall: 0.8590
#
# Epoch 00008: loss improved from -0.89759 to -0.89834, saving model to unet_lung_seg.hdf5
# Epoch 9/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9099 - dice_coef: 0.9099 - binary_accuracy: 0.9452 - mean_iou: 0.8374 - sensitivity: 0.9102 - specificity: 0.9608 - precision: 0.9164 - recall: 0.9102 - val_loss: -0.9292 - val_dice_coef: 0.9292 - val_binary_accuracy: 0.9583 - val_mean_iou: 0.8693 - val_sensitivity: 0.9265 - val_specificity: 0.9723 - val_precision: 0.9337 - val_recall: 0.9265
#
# Epoch 00009: loss improved from -0.89834 to -0.91112, saving model to unet_lung_seg.hdf5
# Epoch 10/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9151 - dice_coef: 0.9151 - binary_accuracy: 0.9480 - mean_iou: 0.8463 - sensitivity: 0.9164 - specificity: 0.9626 - precision: 0.9200 - recall: 0.9164 - val_loss: -0.9234 - val_dice_coef: 0.9234 - val_binary_accuracy: 0.9573 - val_mean_iou: 0.8607 - val_sensitivity: 0.8793 - val_specificity: 0.9909 - val_precision: 0.9759 - val_recall: 0.8793
#
# Epoch 00010: loss improved from -0.91112 to -0.91419, saving model to unet_lung_seg.hdf5
# Epoch 11/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9232 - dice_coef: 0.9232 - binary_accuracy: 0.9530 - mean_iou: 0.8597 - sensitivity: 0.9198 - specificity: 0.9690 - precision: 0.9319 - recall: 0.9198 - val_loss: -0.9356 - val_dice_coef: 0.9356 - val_binary_accuracy: 0.9623 - val_mean_iou: 0.8800 - val_sensitivity: 0.9219 - val_specificity: 0.9800 - val_precision: 0.9508 - val_recall: 0.9219
#
# Epoch 00011: loss improved from -0.91419 to -0.92425, saving model to unet_lung_seg.hdf5
# Epoch 12/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9246 - dice_coef: 0.9246 - binary_accuracy: 0.9536 - mean_iou: 0.8620 - sensitivity: 0.9279 - specificity: 0.9651 - precision: 0.9266 - recall: 0.9279 - val_loss: -0.9146 - val_dice_coef: 0.9146 - val_binary_accuracy: 0.9527 - val_mean_iou: 0.8444 - val_sensitivity: 0.8565 - val_specificity: 0.9940 - val_precision: 0.9836 - val_recall: 0.8565
#
# Epoch 00012: loss improved from -0.92425 to -0.92669, saving model to unet_lung_seg.hdf5
# Epoch 13/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9239 - dice_coef: 0.9239 - binary_accuracy: 0.9541 - mean_iou: 0.8613 - sensitivity: 0.9211 - specificity: 0.9696 - precision: 0.9333 - recall: 0.9211 - val_loss: -0.9352 - val_dice_coef: 0.9352 - val_binary_accuracy: 0.9625 - val_mean_iou: 0.8794 - val_sensitivity: 0.9113 - val_specificity: 0.9848 - val_precision: 0.9618 - val_recall: 0.9113
#
# Epoch 00013: loss improved from -0.92669 to -0.92897, saving model to unet_lung_seg.hdf5
# Epoch 14/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9348 - dice_coef: 0.9348 - binary_accuracy: 0.9599 - mean_iou: 0.8793 - sensitivity: 0.9326 - specificity: 0.9722 - precision: 0.9411 - recall: 0.9326 - val_loss: -0.9450 - val_dice_coef: 0.9450 - val_binary_accuracy: 0.9669 - val_mean_iou: 0.8969 - val_sensitivity: 0.9571 - val_specificity: 0.9718 - val_precision: 0.9344 - val_recall: 0.9571
#
# Epoch 00014: loss improved from -0.92897 to -0.93503, saving model to unet_lung_seg.hdf5
# Epoch 15/40
# 302/302 [==============================] - 126s 416ms/step - loss: -0.9386 - dice_coef: 0.9386 - binary_accuracy: 0.9626 - mean_iou: 0.8858 - sensitivity: 0.9374 - specificity: 0.9741 - precision: 0.9430 - recall: 0.9374 - val_loss: -0.9369 - val_dice_coef: 0.9369 - val_binary_accuracy: 0.9633 - val_mean_iou: 0.8819 - val_sensitivity: 0.9132 - val_specificity: 0.9851 - val_precision: 0.9626 - val_recall: 0.9132
#
# Epoch 00015: loss improved from -0.93503 to -0.93908, saving model to unet_lung_seg.hdf5
# Epoch 16/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9409 - dice_coef: 0.9409 - binary_accuracy: 0.9641 - mean_iou: 0.8899 - sensitivity: 0.9371 - specificity: 0.9763 - precision: 0.9476 - recall: 0.9371 - val_loss: -0.9381 - val_dice_coef: 0.9381 - val_binary_accuracy: 0.9641 - val_mean_iou: 0.8839 - val_sensitivity: 0.9106 - val_specificity: 0.9873 - val_precision: 0.9678 - val_recall: 0.9106
#
# Epoch 00016: loss improved from -0.93908 to -0.94038, saving model to unet_lung_seg.hdf5
# Epoch 17/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9433 - dice_coef: 0.9433 - binary_accuracy: 0.9646 - mean_iou: 0.8942 - sensitivity: 0.9401 - specificity: 0.9760 - precision: 0.9495 - recall: 0.9401 - val_loss: -0.9447 - val_dice_coef: 0.9447 - val_binary_accuracy: 0.9674 - val_mean_iou: 0.8956 - val_sensitivity: 0.9308 - val_specificity: 0.9835 - val_precision: 0.9595 - val_recall: 0.9308
#
# Epoch 00017: loss improved from -0.94038 to -0.94363, saving model to unet_lung_seg.hdf5
# Epoch 18/40
# 302/302 [==============================] - 126s 416ms/step - loss: -0.9463 - dice_coef: 0.9463 - binary_accuracy: 0.9666 - mean_iou: 0.8995 - sensitivity: 0.9435 - specificity: 0.9778 - precision: 0.9517 - recall: 0.9435 - val_loss: -0.9497 - val_dice_coef: 0.9497 - val_binary_accuracy: 0.9699 - val_mean_iou: 0.9047 - val_sensitivity: 0.9495 - val_specificity: 0.9792 - val_precision: 0.9504 - val_recall: 0.9495
#
# Epoch 00018: loss improved from -0.94363 to -0.94687, saving model to unet_lung_seg.hdf5
# Epoch 19/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9458 - dice_coef: 0.9458 - binary_accuracy: 0.9661 - mean_iou: 0.8990 - sensitivity: 0.9420 - specificity: 0.9777 - precision: 0.9527 - recall: 0.9420 - val_loss: -0.9431 - val_dice_coef: 0.9431 - val_binary_accuracy: 0.9669 - val_mean_iou: 0.8928 - val_sensitivity: 0.9152 - val_specificity: 0.9894 - val_precision: 0.9733 - val_recall: 0.9152
#
# Epoch 00019: loss did not improve from -0.94687
# Epoch 20/40
# 302/302 [==============================] - 125s 414ms/step - loss: -0.9484 - dice_coef: 0.9484 - binary_accuracy: 0.9678 - mean_iou: 0.9031 - sensitivity: 0.9427 - specificity: 0.9798 - precision: 0.9564 - recall: 0.9427 - val_loss: -0.9528 - val_dice_coef: 0.9528 - val_binary_accuracy: 0.9720 - val_mean_iou: 0.9104 - val_sensitivity: 0.9461 - val_specificity: 0.9835 - val_precision: 0.9603 - val_recall: 0.9461
#
# Epoch 00020: loss improved from -0.94687 to -0.94932, saving model to unet_lung_seg.hdf5
# Epoch 21/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9514 - dice_coef: 0.9514 - binary_accuracy: 0.9706 - mean_iou: 0.9084 - sensitivity: 0.9470 - specificity: 0.9812 - precision: 0.9578 - recall: 0.9470 - val_loss: -0.9475 - val_dice_coef: 0.9475 - val_binary_accuracy: 0.9691 - val_mean_iou: 0.9003 - val_sensitivity: 0.9293 - val_specificity: 0.9865 - val_precision: 0.9666 - val_recall: 0.9293
#
# Epoch 00021: loss improved from -0.94932 to -0.95138, saving model to unet_lung_seg.hdf5
# Epoch 22/40
# 302/302 [==============================] - 125s 413ms/step - loss: -0.9523 - dice_coef: 0.9523 - binary_accuracy: 0.9707 - mean_iou: 0.9101 - sensitivity: 0.9473 - specificity: 0.9814 - precision: 0.9593 - recall: 0.9473 - val_loss: -0.9519 - val_dice_coef: 0.9519 - val_binary_accuracy: 0.9715 - val_mean_iou: 0.9084 - val_sensitivity: 0.9397 - val_specificity: 0.9855 - val_precision: 0.9646 - val_recall: 0.9397
#
# Epoch 00022: loss improved from -0.95138 to -0.95244, saving model to unet_lung_seg.hdf5
# Epoch 23/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9546 - dice_coef: 0.9546 - binary_accuracy: 0.9719 - mean_iou: 0.9141 - sensitivity: 0.9507 - specificity: 0.9817 - precision: 0.9601 - recall: 0.9507 - val_loss: -0.9468 - val_dice_coef: 0.9468 - val_binary_accuracy: 0.9677 - val_mean_iou: 0.9000 - val_sensitivity: 0.9671 - val_specificity: 0.9686 - val_precision: 0.9284 - val_recall: 0.9671
#
# Epoch 00023: loss improved from -0.95244 to -0.95403, saving model to unet_lung_seg.hdf5
# Epoch 24/40
# 302/302 [==============================] - 125s 412ms/step - loss: -0.9520 - dice_coef: 0.9520 - binary_accuracy: 0.9707 - mean_iou: 0.9093 - sensitivity: 0.9485 - specificity: 0.9810 - precision: 0.9574 - recall: 0.9485 - val_loss: -0.9567 - val_dice_coef: 0.9567 - val_binary_accuracy: 0.9740 - val_mean_iou: 0.9172 - val_sensitivity: 0.9534 - val_specificity: 0.9834 - val_precision: 0.9602 - val_recall: 0.9534
#
# Epoch 00024: loss did not improve from -0.95403
# Epoch 25/40
# 302/302 [==============================] - 125s 413ms/step - loss: -0.9551 - dice_coef: 0.9551 - binary_accuracy: 0.9730 - mean_iou: 0.9150 - sensitivity: 0.9518 - specificity: 0.9823 - precision: 0.9598 - recall: 0.9518 - val_loss: -0.9586 - val_dice_coef: 0.9586 - val_binary_accuracy: 0.9746 - val_mean_iou: 0.9206 - val_sensitivity: 0.9769 - val_specificity: 0.9743 - val_precision: 0.9410 - val_recall: 0.9769
#
# Epoch 00025: loss did not improve from -0.95403
# Epoch 26/40
# 302/302 [==============================] - 125s 415ms/step - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9720 - mean_iou: 0.9137 - sensitivity: 0.9517 - specificity: 0.9810 - precision: 0.9590 - recall: 0.9517 - val_loss: -0.9638 - val_dice_coef: 0.9638 - val_binary_accuracy: 0.9782 - val_mean_iou: 0.9301 - val_sensitivity: 0.9578 - val_specificity: 0.9875 - val_precision: 0.9699 - val_recall: 0.9578
#
# Epoch 00026: loss improved from -0.95403 to -0.95477, saving model to unet_lung_seg.hdf5
# Epoch 27/40
# 302/302 [==============================] - 127s 420ms/step - loss: -0.9533 - dice_coef: 0.9533 - binary_accuracy: 0.9719 - mean_iou: 0.9123 - sensitivity: 0.9496 - specificity: 0.9814 - precision: 0.9593 - recall: 0.9496 - val_loss: -0.9605 - val_dice_coef: 0.9605 - val_binary_accuracy: 0.9765 - val_mean_iou: 0.9239 - val_sensitivity: 0.9453 - val_specificity: 0.9902 - val_precision: 0.9761 - val_recall: 0.9453
#
# Epoch 00027: loss improved from -0.95477 to -0.95529, saving model to unet_lung_seg.hdf5
# Epoch 28/40
# 302/302 [==============================] - 126s 416ms/step - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9751 - mean_iou: 0.9240 - sensitivity: 0.9573 - specificity: 0.9834 - precision: 0.9641 - recall: 0.9573 - val_loss: -0.9495 - val_dice_coef: 0.9495 - val_binary_accuracy: 0.9708 - val_mean_iou: 0.9037 - val_sensitivity: 0.9117 - val_specificity: 0.9963 - val_precision: 0.9905 - val_recall: 0.9117
#
# Epoch 00028: loss improved from -0.95529 to -0.95768, saving model to unet_lung_seg.hdf5
# Epoch 29/40
# 302/302 [==============================] - 126s 416ms/step - loss: -0.9565 - dice_coef: 0.9565 - binary_accuracy: 0.9735 - mean_iou: 0.9175 - sensitivity: 0.9511 - specificity: 0.9834 - precision: 0.9633 - recall: 0.9511 - val_loss: -0.9606 - val_dice_coef: 0.9606 - val_binary_accuracy: 0.9767 - val_mean_iou: 0.9244 - val_sensitivity: 0.9418 - val_specificity: 0.9921 - val_precision: 0.9804 - val_recall: 0.9418
#
# Epoch 00029: loss improved from -0.95768 to -0.95783, saving model to unet_lung_seg.hdf5
# Epoch 30/40
# 302/302 [==============================] - 127s 420ms/step - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9742 - mean_iou: 0.9209 - sensitivity: 0.9549 - specificity: 0.9831 - precision: 0.9632 - recall: 0.9549 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9789 - val_mean_iou: 0.9323 - val_sensitivity: 0.9576 - val_specificity: 0.9886 - val_precision: 0.9724 - val_recall: 0.9576
#
# Epoch 00030: loss did not improve from -0.95783
# Epoch 31/40
# 302/302 [==============================] - 135s 448ms/step - loss: -0.9578 - dice_coef: 0.9578 - binary_accuracy: 0.9741 - mean_iou: 0.9200 - sensitivity: 0.9539 - specificity: 0.9834 - precision: 0.9632 - recall: 0.9539 - val_loss: -0.9501 - val_dice_coef: 0.9501 - val_binary_accuracy: 0.9713 - val_mean_iou: 0.9048 - val_sensitivity: 0.9065 - val_specificity: 0.9992 - val_precision: 0.9981 - val_recall: 0.9065
#
# Epoch 00031: loss did not improve from -0.95783
# Epoch 32/40
# 302/302 [==============================] - 135s 448ms/step - loss: -0.9567 - dice_coef: 0.9567 - binary_accuracy: 0.9731 - mean_iou: 0.9176 - sensitivity: 0.9507 - specificity: 0.9835 - precision: 0.9640 - recall: 0.9507 - val_loss: -0.9546 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9736 - val_mean_iou: 0.9131 - val_sensitivity: 0.9189 - val_specificity: 0.9973 - val_precision: 0.9930 - val_recall: 0.9189
#
# Epoch 00032: loss did not improve from -0.95783
# Epoch 33/40
# 302/302 [==============================] - 137s 453ms/step - loss: -0.9589 - dice_coef: 0.9589 - binary_accuracy: 0.9748 - mean_iou: 0.9219 - sensitivity: 0.9539 - specificity: 0.9845 - precision: 0.9655 - recall: 0.9539 - val_loss: -0.9590 - val_dice_coef: 0.9590 - val_binary_accuracy: 0.9760 - val_mean_iou: 0.9213 - val_sensitivity: 0.9304 - val_specificity: 0.9958 - val_precision: 0.9895 - val_recall: 0.9304
#
# Epoch 00033: loss improved from -0.95783 to -0.95904, saving model to unet_lung_seg.hdf5
# Epoch 34/40
# 302/302 [==============================] - 142s 469ms/step - loss: -0.9595 - dice_coef: 0.9595 - binary_accuracy: 0.9750 - mean_iou: 0.9228 - sensitivity: 0.9542 - specificity: 0.9847 - precision: 0.9660 - recall: 0.9542 - val_loss: -0.9709 - val_dice_coef: 0.9709 - val_binary_accuracy: 0.9824 - val_mean_iou: 0.9434 - val_sensitivity: 0.9631 - val_specificity: 0.9912 - val_precision: 0.9788 - val_recall: 0.9631
#
# Epoch 00034: loss improved from -0.95904 to -0.95968, saving model to unet_lung_seg.hdf5
# Epoch 35/40
# 302/302 [==============================] - 141s 469ms/step - loss: -0.9598 - dice_coef: 0.9598 - binary_accuracy: 0.9754 - mean_iou: 0.9234 - sensitivity: 0.9566 - specificity: 0.9839 - precision: 0.9641 - recall: 0.9566 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9804 - val_mean_iou: 0.9363 - val_sensitivity: 0.9474 - val_specificity: 0.9950 - val_precision: 0.9876 - val_recall: 0.9474
#
# Epoch 00035: loss did not improve from -0.95968
# Epoch 36/40
# 302/302 [==============================] - 144s 476ms/step - loss: -0.9595 - dice_coef: 0.9595 - binary_accuracy: 0.9746 - mean_iou: 0.9231 - sensitivity: 0.9546 - specificity: 0.9842 - precision: 0.9656 - recall: 0.9546 - val_loss: -0.9723 - val_dice_coef: 0.9723 - val_binary_accuracy: 0.9831 - val_mean_iou: 0.9462 - val_sensitivity: 0.9745 - val_specificity: 0.9875 - val_precision: 0.9702 - val_recall: 0.9745
#
# Epoch 00036: loss improved from -0.95968 to -0.96064, saving model to unet_lung_seg.hdf5
# Epoch 37/40
# 302/302 [==============================] - 146s 484ms/step - loss: -0.9604 - dice_coef: 0.9604 - binary_accuracy: 0.9752 - mean_iou: 0.9245 - sensitivity: 0.9558 - specificity: 0.9845 - precision: 0.9663 - recall: 0.9558 - val_loss: -0.9718 - val_dice_coef: 0.9718 - val_binary_accuracy: 0.9830 - val_mean_iou: 0.9453 - val_sensitivity: 0.9658 - val_specificity: 0.9909 - val_precision: 0.9780 - val_recall: 0.9658
#
# Epoch 00037: loss improved from -0.96064 to -0.96105, saving model to unet_lung_seg.hdf5
# Epoch 38/40
# 302/302 [==============================] - 146s 483ms/step - loss: -0.9607 - dice_coef: 0.9607 - binary_accuracy: 0.9761 - mean_iou: 0.9250 - sensitivity: 0.9562 - specificity: 0.9851 - precision: 0.9663 - recall: 0.9562 - val_loss: -0.9660 - val_dice_coef: 0.9660 - val_binary_accuracy: 0.9794 - val_mean_iou: 0.9343 - val_sensitivity: 0.9648 - val_specificity: 0.9863 - val_precision: 0.9673 - val_recall: 0.9648
#
# Epoch 00038: loss improved from -0.96105 to -0.96111, saving model to unet_lung_seg.hdf5
# Epoch 39/40
# 302/302 [==============================] - 146s 484ms/step - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9759 - mean_iou: 0.9259 - sensitivity: 0.9579 - specificity: 0.9844 - precision: 0.9656 - recall: 0.9579 - val_loss: -0.9755 - val_dice_coef: 0.9755 - val_binary_accuracy: 0.9851 - val_mean_iou: 0.9525 - val_sensitivity: 0.9736 - val_specificity: 0.9907 - val_precision: 0.9777 - val_recall: 0.9736
#
# Epoch 00039: loss improved from -0.96111 to -0.96157, saving model to unet_lung_seg.hdf5
# Epoch 40/40
# 302/302 [==============================] - 148s 491ms/step - loss: -0.9622 - dice_coef: 0.9622 - binary_accuracy: 0.9766 - mean_iou: 0.9280 - sensitivity: 0.9570 - specificity: 0.9860 - precision: 0.9687 - recall: 0.9570 - val_loss: -0.9723 - val_dice_coef: 0.9723 - val_binary_accuracy: 0.9833 - val_mean_iou: 0.9462 - val_sensitivity: 0.9648 - val_specificity: 0.9917 - val_precision: 0.9800 - val_recall: 0.9648
#
# Epoch 00040: loss did not improve from -0.96157

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_recall = history.history['recall']
validation_recall = history.history['val_recall']

training_precision = history.history['precision']
validation_precision = history.history['val_precision']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_recall, 'r--')
axs[0].plot(epoch_count, validation_recall, 'b-')
axs[0].legend(['Training recall', 'Validation recall'])

axs[1].plot(epoch_count, training_precision, 'r--')
axs[1].plot(epoch_count, validation_precision, 'b-')
axs[1].legend(['Training precision', 'Validation precision'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_mean_iou = history.history['mean_iou']
validation_mean_iou = history.history['val_mean_iou']

training_specificity = history.history['specificity']
validation_specificity = history.history['val_specificity']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_mean_iou, 'r--')
axs[0].plot(epoch_count, validation_mean_iou, 'b-')
axs[0].legend(['Training mean_iou', 'Validation mean_iou'])

axs[1].plot(epoch_count, training_specificity, 'r--')
axs[1].plot(epoch_count, validation_specificity, 'b-')
axs[1].legend(['Training specificity', 'Validation specificity'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_dice_coef = history.history['dice_coef']
validation_dice_coef = history.history['val_dice_coef']

training_sensitivity = history.history['sensitivity']
validation_sensitivity = history.history['val_sensitivity']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_dice_coef, 'r--')
axs[0].plot(epoch_count, validation_dice_coef, 'b-')
axs[0].legend(['Training dice_coef', 'Validation dice_coef'])

axs[1].plot(epoch_count, training_sensitivity, 'r--')
axs[1].plot(epoch_count, validation_sensitivity, 'b-')
axs[1].legend(['Training sensitivity', 'Validation sensitivity'])

# %%
test_gen = test_generator(test_files, target_size=(512,512))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result(segmentation_test_dir, results, test_files)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 100/100 [==============================] - 36s 342ms/step

# %%
image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0003_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0003_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0003_0_dilate.png")

fig, axs = plt.subplots(4, 3, figsize=(16, 16))

axs[0, 0].set_title("Predicted")
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("Gold Std.")
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0003_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0003_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0003_0_dilate.png")

axs[1, 0].set_title("Predicted")
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("Gold Std.")
axs[1, 1].imshow(add_colored_mask(image, mask_image))
axs[1, 2].set_title("Diff.")
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0020_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0020_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/CHNCXR_0020_0_dilate.png")

axs[2, 0].set_title("Predicted")
axs[2, 0].imshow(add_colored_mask(image, predict_image))
axs[2, 1].set_title("Gold Std.")
axs[2, 1].imshow(add_colored_mask(image, mask_image))
axs[2, 2].set_title("Diff.")
axs[2, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0016_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0016_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/research2/segmentation/test++/MCUCXR_0016_0_dilate.png")

axs[3, 0].set_title("Predicted")
axs[3, 0].imshow(add_colored_mask(image, predict_image))
axs[3, 1].set_title("Gold Std.")
axs[3, 1].imshow(add_colored_mask(image, mask_image))
axs[3, 2].set_title("Diff.")
axs[3, 2].imshow(diff_mask(mask_image, predict_image))

# %%
model = load_model("/content/unet_lung_seg.hdf5",custom_object={dice_co})
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 128 147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 512, 512, 32) 8224        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 64) 0           conv2d_transpose[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 384 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 32) 18464       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 128 442496      concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 192 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 128 147584      conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 96) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 512, 32) 27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 256 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 147520      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 512, 512, 128 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 36896       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 512, 512, 160 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 512, 512, 32) 46112       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 512, 512, 1)  33          conv2d_29[0][0]
# ==================================================================================================
# Total params: 9,041,601
# Trainable params: 9,041,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import PIL

# %%
img_size = (512,512)
last_conv_layer_name="conv2d_30"
_img = load_img("CHNCXR_0003_0.png",target_size=img_size)
plt.imshow(_img)
_img = _img.convert("L")

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
img_array = img_to_array(_img)

# Make model
model = model_builder(weights="unet_lung_seg.hdf5")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-d49452661e93> in <module>()
#       2
#       3 # Make model
# ----> 4 model = model_builder(weights="unet_lung_seg.hdf5")
#       5
#       6 # Remove last layer's softmax
#
# NameError: name 'model_builder' is not defined
